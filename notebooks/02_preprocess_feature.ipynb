# %%
import sys
sys.path.append("..")

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from src.features.rfm import build_rfm
from src.features.basket import build_basket
from src.features.time_features import build_monthly_timeseries

plt.rcParams["figure.figsize"] = (8,4)
sns.set_style("whitegrid")

# %%
df = pd.read_parquet("../data/processed/cleaned.parquet")

print(df.shape)
df.head()
# Out:
# (9800, 18)
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156   8/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156   8/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688   12/6/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
rfm = build_rfm(df)

print(rfm.shape)
rfm.head()
# Out:
# (793, 4)
#   Customer ID  Recency  Frequency  Monetary
# 0    AA-10315      185          5  5563.560
# 1    AA-10375       20          9  1056.390
# 2    AA-10480      260          4  1790.512
# 3    AA-10645       56          6  5086.935
# 4    AB-10015      416          3   886.156

# %%
rfm.describe()
rfm.hist(bins=30)
plt.tight_layout()
plt.show()

# %%
basket = build_basket(df)

print(basket.shape)
basket.head()
# Out:
# (4922, 1850)
# Product Name        Order ID  \
# 0             CA-2015-100006
# 1             CA-2015-100090
# 2             CA-2015-100293
# 3             CA-2015-100328
# 4             CA-2015-100363
#
# Product Name  "While you Were Out" Message Book, One Form per Page  \
# 0                                                             0
# 1                                                             0
# 2                                                             0
# 3                                                             0
# 4                                                             0
#
# Product Name  #10 Gummed Flap White Envelopes, 100/Box  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
#
# ...

# %%
basket.drop(columns=["Order ID"]).sum().sort_values(ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 basket.sum().sort_values(ascending=False).head(10)
#
# File c:\Users\Huy\anaconda3\Lib\site-packages\pandas\core\series.py:3888, in Series.sort_values(self, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    3886 else:
#    3887     values_to_sort = self._values
# -> 3888 sorted_index = nargsort(values_to_sort, kind, bool(ascending), na_position)
#    3890 if is_range_indexer(sorted_index, len(sorted_index)):
#    3891     if inplace:
#
# File c:\Users\Huy\anaconda3\Lib\site-packages\pandas\core\sorting.py:439, in nargsort(items, kind, ascending, na_position, key, mask)
#     437     non_nans = non_nans[::-1]
#     438     non_nan_idx = non_nan_idx[::-1]
# --> 439 indexer = non_nan_idx[non_nans.argsort(kind=kind)]
#     440 if not ascending:
#     441     indexer = indexer[::-1]
#
# ...

# %%
ts = build_monthly_timeseries(df)

print(ts.shape)
ts.head()

# %%
plt.plot(ts["date"], ts["sales"])
plt.title("Monthly Sales")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.show()

# %%
rfm.to_parquet("../data/processed/rfm.parquet", index=False)
basket.to_parquet("../data/processed/basket.parquet", index=False)
ts.to_csv("../data/processed/timeseries_monthly.csv", index=False)

print("Saved all features successfully!")

# %%
# !dir ../data/processed
